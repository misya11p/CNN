# %%
import tensorflow as tf

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# 2022-06-07 22:10:59.163543: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-07 22:10:59.163563: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11221669221268274801
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  locality {
#    bus_id: 1
#  }
#  incarnation: 8176362752640529684
#  physical_device_desc: "device: 0, name: METAL, pci bus id: <undefined>"
#  xla_global_id: -1]

# %%
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten

# %%
model = keras.Sequential([
    Conv2D(32, kernel_size=3, input_shape=(28, 28, 1), activation='relu'),
    Conv2D(64, kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 128)               1179776
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['acc'])

# %%
model.fit(train_images, train_labels, batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 2022-06-07 22:30:08.195442: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-07 22:30:08.429622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6394 - acc: 0.9419
# Epoch 2/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0433 - acc: 0.9868
# Epoch 3/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0263 - acc: 0.9915
# Epoch 4/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0193 - acc: 0.9938
# Epoch 5/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0158 - acc: 0.9945
# Epoch 6/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0126 - acc: 0.9958
# Epoch 7/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0105 - acc: 0.9965
# Epoch 8/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0129 - acc: 0.9955
# Epoch 9/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0112 - acc: 0.9964
# Epoch 10/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0079 - acc: 0.9977
